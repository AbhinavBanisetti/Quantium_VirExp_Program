# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
trnsc=pd.read_excel("QVI_transaction_data.xlsx")
trnsc.info()
# No null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
# DATE              264836 non-null int64
# STORE_NBR         264836 non-null int64
# LYLTY_CARD_NBR    264836 non-null int64
# TXN_ID            264836 non-null int64
# PROD_NBR          264836 non-null int64
# PROD_NAME         264836 non-null object
# PROD_QTY          264836 non-null int64
# TOT_SALES         264836 non-null float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
trnsc.describe()
# No anamolies
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# 75%        85.000000       2.000000       9.200000
# max       114.000000     200.000000     650.000000

# %% [markdown]
# #### "PROD_NBR" == "PROD_NAME"
# #### Convert the Date column into Date type Variable
# #### Do some modifications on "PROD_NAME"
# #### seperate package size from the name
# #### seperate company from the "PROD_NAME"
# #### why is "TOT_SALES"  column in decimal?? is it representing % then why is the max value 650

# %%
transc=trnsc.copy()
import re
packages=transc["PROD_NAME"].apply(lambda x:x.split()[-1])
packages
# Out:
# 0         SeaSalt175g
# 1                175g
# 2                170g
# 3                175g
# 4                150g
#              ...
# 264831           175g
# 264832           175g
# 264833           170g
# 264834           150g
# 264835           175g
# Name: PROD_NAME, Length: 264836, dtype: object

# %%
packages=np.where(packages=='Salt',"135g",packages)
packages=pd.Series(packages)
packages.unique()
# Out:
# array(['SeaSalt175g', '175g', '170g', '150g', '300g', '330g', '210g',
#        '210G', '270g', '220g', '125g', '110g', '134g', '150G',
#        'Chli&S/Cream175G', 'Chckn175g', '380g', 'Chicken270g', '180g',
#        '165g', '135g', '250g', 'Ht300g', 'Chs&Onion170g', '200g', '160g',
#        'CutSalt/Vinegr175g', '190g', '90g', '70g'], dtype=object)

# %% [markdown]
# #### SeaSalt175g
# #### Chli&S/Cream175G
# #### Chckn175g
# #### Chicken270g
# #### Chs&Onion170g
# #### Ht300g
# #### CutSalt/Vinegr175g

# %%
packages=packages.apply(lambda x:x[-4:].split('g')[0])
# adding new colum to "transc"
transc["Pkg_size_grm"]=packages

# Removing the numbers from the names of chips
transc["PROD_NAME"]=transc["PROD_NAME"].apply(lambda x:x[:-4])
transc["PROD_NAME"]=np.where(transc["PROD_NAME"]=='Kettle 135g Swt Pot Sea ','Kettle Swt Pot Sea Salt',transc["PROD_NAME"])

#Converting into Lower case letters
transc["PROD_NAME"]=transc["PROD_NAME"].apply(lambda x:x.lower())

# Coverting the DATE column to the desired format
date_offsets = transc["DATE"]
base_date = pd.Timestamp('1899-12-30')  # check this!
dates = pd.Series([
    base_date + pd.DateOffset(date_offset) 
    for date_offset in date_offsets
])
transc["DATE"]=dates

# %%
transc["Pkg_size_grm"].unique()
# Out:
# array(['175', '170', '150', '300', '330', '210', '210G', '270', '220',
#        '125', '110', '134', '150G', '175G', '380', '180', '165', '135',
#        '250', '200', '160', '190', '90', '70'], dtype=object)

# %%
def cleaning(a):
    if len(a)>3:
        return a[:-1]
    else:
        return a
    
transc["Pkg_size_grm"]=transc["Pkg_size_grm"].apply(cleaning)

# %%
transc["Pkg_size_grm"]
# Out:
# 0         175
# 1         175
# 2         170
# 3         175
# 4         150
#          ...
# 264831    175
# 264832    175
# 264833    170
# 264834    150
# 264835    175
# Name: Pkg_size_grm, Length: 264836, dtype: object

# %%
convert_dict={"Pkg_size_grm":int}
transc=transc.astype(convert_dict)
transc.describe()
# Out:
#           STORE_NBR  LYLTY_CARD_NBR        TXN_ID       PROD_NBR  \
# count  264836.00000    2.648360e+05  2.648360e+05  264836.000000
# mean      135.08011    1.355495e+05  1.351583e+05      56.583157
# std        76.78418    8.057998e+04  7.813303e+04      32.826638
# min         1.00000    1.000000e+03  1.000000e+00       1.000000
# 25%        70.00000    7.002100e+04  6.760150e+04      28.000000
# 50%       130.00000    1.303575e+05  1.351375e+05      56.000000
# 75%       203.00000    2.030942e+05  2.027012e+05      85.000000
# max       272.00000    2.373711e+06  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES   Pkg_size_grm
# count  264836.000000  264836.000000  264836.000000
# mean        1.907309       7.304200     182.427004
# std         0.643654       3.083226      64.327196
# min         1.000000       1.500000      70.000000
# 25%         2.000000       5.400000     150.000000
# 50%         2.000000       7.400000     170.000000
# 75%         2.000000       9.200000     175.000000
# max       200.000000     650.000000     380.000000

# %%
# The MAX of "PROD_QTY" is 200!
# Let us examine this outlier
transc[transc["PROD_QTY"]==200]

# The same customer bought 200 chips twice for the same kind of chips
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                           PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm
# 69762  dorito corn chp     supreme        200      650.0           380
# 69763  dorito corn chp     supreme        200      650.0           380

# %%
# lets see if this customer has any other transactions
transc[transc["LYLTY_CARD_NBR"]==226000]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                           PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm
# 69762  dorito corn chp     supreme        200      650.0           380
# 69763  dorito corn chp     supreme        200      650.0           380

# %% [markdown]
# It looks like this customer has only had the two transactions over the year and is
# not an ordinary retail customer. The customer might be buying chips for commercial
# purposes instead. We'll remove this loyalty card number from further analysis.

# %%
transc.drop(index=list(transc[transc["LYLTY_CARD_NBR"]==226000].index),inplace=True)
transc.shape
# Out:
# (264834, 9)

# %%
transc["salsa_y_n"]=pd.Series(transc["PROD_NAME"].apply(lambda x: 'salsa' in x))
transc
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264831 2019-03-09        272          272319  270088        89
# 264832 2018-08-13        272          272358  270154        74
# 264833 2018-11-06        272          272379  270187        51
# 264834 2018-12-27        272          272379  270188        42
# 264835 2018-09-22        272          272380  270189        74
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         natural chip        compny seasalt         2        6.0
# 1                       ccs nacho cheese             3        6.3
# 2         smiths crinkle cut  chips chicken          2        2.9
# 3         smiths chip thinly  s/cream&onion          5       15.0
# 4       kettle tortilla chpshny&jlpno chili          3       13.8
# ...                                      ...       ...        ...
# 264831   kettle sweet chilli and sour cream          2       10.8
# 264832             tostitos splash of  lime          1        4.4
# 264833                  doritos mexicana             2        8.8
# 264834   doritos corn chip mexican jalapeno          2        7.8
# 264835             tostitos splash of  lime          2        8.8
#
#         Pkg_size_grm  salsa_y_n
# 0                175      False
# 1                175      False
# 2                170      False
# 3                175      False
# 4                150      False
# ...              ...        ...
# 264831           175      False
# 264832           175      False
# 264833           170      False
# 264834           150      False
# 264835           175      False
#
# [264834 rows x 10 columns]

# %%
transc[transc["salsa_y_n"]==True]["PROD_NAME"]
# these are not chips
# so we will be deleting them
# Out:
# 5         old el paso salsa   dip tomato mild
# 25        old el paso salsa   dip tomato mild
# 32        red rock deli sr    salsa & mzzrlla
# 44           smiths crinkle cut  tomato salsa
# 63                 doritos salsa       medium
#                           ...
# 264675     old el paso salsa   dip tomato med
# 264678              woolworths mild     salsa
# 264719       smiths crinkle cut  tomato salsa
# 264734                    doritos salsa mild
# 264780    red rock deli sr    salsa & mzzrlla
# Name: PROD_NAME, Length: 18094, dtype: object

# %%
pd.DataFrame(transc[transc["salsa_y_n"]==True]["PROD_NAME"].apply(lambda x: 'old' in x)==True)['PROD_NAME'].value_counts()
# Out:
# True     9324
# False    8770
# Name: PROD_NAME, dtype: int64

# %% [markdown]
# All of the products belonging to the 'old el paso' brand are not Chips but Salsa.

# %%
transc.drop(index=list(transc[transc["salsa_y_n"]==True].index),inplace=True)
transc.drop(columns="salsa_y_n",inplace=True)
transc
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264831 2019-03-09        272          272319  270088        89
# 264832 2018-08-13        272          272358  270154        74
# 264833 2018-11-06        272          272379  270187        51
# 264834 2018-12-27        272          272379  270188        42
# 264835 2018-09-22        272          272380  270189        74
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         natural chip        compny seasalt         2        6.0
# 1                       ccs nacho cheese             3        6.3
# 2         smiths crinkle cut  chips chicken          2        2.9
# 3         smiths chip thinly  s/cream&onion          5       15.0
# 4       kettle tortilla chpshny&jlpno chili          3       13.8
# ...                                      ...       ...        ...
# 264831   kettle sweet chilli and sour cream          2       10.8
# 264832             tostitos splash of  lime          1        4.4
# 264833                  doritos mexicana             2        8.8
# 264834   doritos corn chip mexican jalapeno          2        7.8
# 264835             tostitos splash of  lime          2        8.8
#
#         Pkg_size_grm
# 0                175
# 1                175
# 2                170
# 3                175
# 4                150
# ...              ...
# 264831           175
# 264832           175
# 264833           170
# 264834           150
# 264835           175
#
# [246740 rows x 9 columns]

# %%
transc[transc["TXN_ID"]==230356]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 79055 2018-12-07        229          229001  230356        55
# 79056 2018-12-07        229          229001  230356        20
# 79057 2018-12-07        229          229001  230356        86
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm
# 79055  snbts whlgrn crisps cheddr&mstrd         2        3.4            90
# 79056      doritos cheese      supreme          2       11.4           330
# 79057                    cheetos puffs          2        5.6           165

# %% [markdown]
# "TXN_ID" column need not be unique

# %%
time_series=pd.DataFrame(transc["DATE"].value_counts())
time_series.reset_index(inplace=True)
time_series.columns=["DATE","No_of_TRANSC"]
time_series.sort_values(by=["DATE"],ascending=True,inplace=True)
time_series
# Out:
#           DATE  No_of_TRANSC
# 252 2018-07-01           663
# 302 2018-07-02           650
# 177 2018-07-03           674
# 214 2018-07-04           669
# 266 2018-07-05           660
# ..         ...           ...
# 280 2019-06-26           657
# 211 2019-06-27           669
# 185 2019-06-28           673
# 56  2019-06-29           703
# 54  2019-06-30           704
#
# [364 rows x 2 columns]

# %% [markdown]
# There's only 364 rows, meaning only 364 dates which indicates a missing date. Let's
# create a sequence of dates from 1 Jul 2018 to 30 Jun 2019 and use this to create a
# chart of number of transactions over time to find the missing date.

# %%
'''
sns.barplot(x="DATE",y="No_of_TRANSC",data=time_series)
plt.xticks(rotation=90)
'''
plt.figure(figsize=(20,10))
plt.plot('DATE','No_of_TRANSC',data=time_series,marker='o',markersize=4)

# %%
# zoom in to december and Visualize
filtered_transc=transc.loc[(transc['DATE']>='2018-12-01')&(transc['DATE']<='2018-12-31')]
filtered_transc=pd.DataFrame(filtered_transc["DATE"].value_counts())
filtered_transc.reset_index(inplace=True)
filtered_transc.columns=["DATE","No_of_TRANSC"]
filtered_transc.sort_values(by=["DATE"],ascending=True,inplace=True)
filtered_transc
# Out:
#          DATE  No_of_TRANSC
# 15 2018-12-01           675
# 25 2018-12-02           655
# 14 2018-12-03           677
# 21 2018-12-04           666
# 23 2018-12-05           660
# 27 2018-12-06           645
# 16 2018-12-07           672
# 29 2018-12-08           622
# 24 2018-12-09           659
# 22 2018-12-10           664
# 13 2018-12-11           686
# 28 2018-12-12           624
# 19 2018-12-13           668
# 10 2018-12-14           697
# 17 2018-12-15           671
# 8  2018-12-16           709
# 7  2018-12-17           729
# 5  2018-12-18           799
# 3  2018-12-19           839
# 4  2018-12-20           808
# 6  2018-12-21           781
# 2  2018-12-22           840
# 1  2018-12-23           853
# 0  2018-12-24           865
# 9  2018-12-26           700
# 11 2018-12-27           690
# 18 2018-12-28           669
# 20 2018-12-29           666
# 12 2018-12-30           686
# 26 2018-12-31           650

# %%
plt.figure(figsize=(20,10))
plt.plot('DATE','No_of_TRANSC',data=filtered_transc,marker='o',markersize=4)

# %% [markdown]
# The no.of transactions per day see a spike in the days leading to christmas...and during the day of christmas the shops are closed so the transactions are 0..and the spike decreases after the christmas.

# %%
# Pkg_size_grm is a Categorical variable actually encoded in numbers
plt.hist(transc['Pkg_size_grm'])
# Out:
# (array([  4515.,  23841.,  71532., 106133.,  12309.,   3169.,   6285.,
#              0.,  12540.,   6416.]),
#  array([ 70., 101., 132., 163., 194., 225., 256., 287., 318., 349., 380.]),
#  <a list of 10 Patch objects>)

# %%
package_freq=pd.DataFrame(transc["Pkg_size_grm"].value_counts())
package_freq.reset_index(inplace=True)
package_freq.columns=["Pkg_size_grm","No_of_TRANSC"]
package_freq.sort_values(by=["Pkg_size_grm"],ascending=True,inplace=True)

plt.figure(figsize=(20,10))
sns.barplot(x="Pkg_size_grm",y="No_of_TRANSC",data=package_freq)

# %%
# Extracting Brand Names
transc["BRAND"]=pd.Series(transc["PROD_NAME"].apply(lambda x:x.split()[0]))
transc
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264831 2019-03-09        272          272319  270088        89
# 264832 2018-08-13        272          272358  270154        74
# 264833 2018-11-06        272          272379  270187        51
# 264834 2018-12-27        272          272379  270188        42
# 264835 2018-09-22        272          272380  270189        74
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         natural chip        compny seasalt         2        6.0
# 1                       ccs nacho cheese             3        6.3
# 2         smiths crinkle cut  chips chicken          2        2.9
# 3         smiths chip thinly  s/cream&onion          5       15.0
# 4       kettle tortilla chpshny&jlpno chili          3       13.8
# ...                                      ...       ...        ...
# 264831   kettle sweet chilli and sour cream          2       10.8
# 264832             tostitos splash of  lime          1        4.4
# 264833                  doritos mexicana             2        8.8
# 264834   doritos corn chip mexican jalapeno          2        7.8
# 264835             tostitos splash of  lime          2        8.8
#
#         Pkg_size_grm     BRAND
# 0                175   natural
# 1                175       ccs
# 2                170    smiths
# 3                175    smiths
# 4                150    kettle
# ...              ...       ...
# 264831           175    kettle
# 264832           175  tostitos
# 264833           170   doritos
# 264834           150   doritos
# 264835           175  tostitos
#
# [246740 rows x 10 columns]

# %% [markdown]
# #### transc["BRAND"].unique()
# #### infuzions , infzns
# #### smith , smiths
# #### sunbites , snbts , grnwves , grain
# #### red , rrd
# #### natural , ncc
# #### ww , woolworths
# #### old --> old el paso
# #### dorito , doritos
# #### burger --> burger rings
# #### french --> french fries

# %%
transc["BRAND"].replace(to_replace=["infzns","smith","snbts","grnwves","grain","rrd","ncc","ww","old","dorito","burger","french"],value=["infuzions","smiths","sunbites","sunbites","sunbites","red","natural","woolworths","old el paso","doritos","burger rings","french fries"],inplace=True)
transc["BRAND"].unique()
# Out:
# array(['natural', 'ccs', 'smiths', 'kettle', 'sunbites', 'doritos',
#        'twisties', 'woolworths', 'thins', 'burger rings', 'cheezels',
#        'infuzions', 'red', 'pringles', 'tyrrells', 'cobs', 'french fries',
#        'tostitos', 'cheetos'], dtype=object)

# %%
brand_freq=pd.DataFrame(transc["BRAND"].value_counts())
brand_freq.reset_index(inplace=True)
brand_freq.columns=["BRAND","No_of_TRANSC"]
brand_freq.sort_values(by=["BRAND"],ascending=True,inplace=True)

plt.figure(figsize=(20,10))
sns.barplot(x="BRAND",y="No_of_TRANSC",data=brand_freq)

# %%
transc['BRAND'].unique()
# Out:
# array(['natural', 'ccs', 'smiths', 'kettle', 'sunbites', 'doritos',
#        'twisties', 'woolworths', 'thins', 'burger rings', 'cheezels',
#        'infuzions', 'red', 'pringles', 'tyrrells', 'cobs', 'french fries',
#        'tostitos', 'cheetos'], dtype=object)

# %%
# Analyzing Customer data
cust=pd.read_csv("QVI_purchase_behaviour.csv")
cust.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
# LYLTY_CARD_NBR      72637 non-null int64
# LIFESTAGE           72637 non-null object
# PREMIUM_CUSTOMER    72637 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
cust["LYLTY_CARD_NBR"].nunique()
# Out:
# 72637

# %%
cust.shape
# Out:
# (72637, 3)

# %%
# there seems to be no missing data or descrepencies in the Dataset
lifestage_freq=pd.DataFrame(cust["LIFESTAGE"].value_counts())
lifestage_freq.reset_index(inplace=True)
lifestage_freq.columns=["LIFESTAGE","freq"]

plt.figure(figsize=(20,10))
sns.barplot(x="LIFESTAGE",y="freq",data=lifestage_freq)

# %%
class_cust_freq=pd.DataFrame(cust["PREMIUM_CUSTOMER"].value_counts())
class_cust_freq.reset_index(inplace=True)
class_cust_freq.columns=["Class","freq"]

plt.figure(figsize=(20,10))
sns.barplot(x="Class",y="freq",data=class_cust_freq)

# %%
lifesize_freq=pd.DataFrame(cust["LIFESTAGE"].value_counts())
lifesize_freq.columns=["Freq"]

plt.figure(figsize=(7,7))
plt.pie(lifesize_freq["Freq"],labels=lifesize_freq.index,shadow=True)
plt.legend(title="Lifestage:")

# %%
cust_class=pd.DataFrame(cust["PREMIUM_CUSTOMER"].value_counts())
cust_class.columns=["Freq"]

plt.figure(figsize=(7,7))
plt.pie(cust_class["Freq"],labels=cust_class.index,shadow=True)
plt.legend(title="Customer class:")

# %%
# For each class of Lifesize how many classes of customers are there? like premium,mainstream,budget...
cust["count"]=1
comb1=cust[["LIFESTAGE","PREMIUM_CUSTOMER","count"]].pivot_table(index=["LIFESTAGE","PREMIUM_CUSTOMER"],aggfunc=sum)

fig,ax=plt.subplots(figsize=(50,20))
sns.barplot(x=comb1.index,y=comb1["count"])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel("(Life Stage,Segment)",fontsize=40)
ax.set_ylabel("count",fontsize=40)
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### Joining the 2 dataframes

# %%
transc
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264831 2019-03-09        272          272319  270088        89
# 264832 2018-08-13        272          272358  270154        74
# 264833 2018-11-06        272          272379  270187        51
# 264834 2018-12-27        272          272379  270188        42
# 264835 2018-09-22        272          272380  270189        74
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         natural chip        compny seasalt         2        6.0
# 1                       ccs nacho cheese             3        6.3
# 2         smiths crinkle cut  chips chicken          2        2.9
# 3         smiths chip thinly  s/cream&onion          5       15.0
# 4       kettle tortilla chpshny&jlpno chili          3       13.8
# ...                                      ...       ...        ...
# 264831   kettle sweet chilli and sour cream          2       10.8
# 264832             tostitos splash of  lime          1        4.4
# 264833                  doritos mexicana             2        8.8
# 264834   doritos corn chip mexican jalapeno          2        7.8
# 264835             tostitos splash of  lime          2        8.8
#
#         Pkg_size_grm     BRAND
# 0                175   natural
# 1                175       ccs
# 2                170    smiths
# 3                175    smiths
# 4                150    kettle
# ...              ...       ...
# 264831           175    kettle
# 264832           175  tostitos
# 264833           170   doritos
# 264834           150   doritos
# 264835           175  tostitos
#
# [246740 rows x 10 columns]

# %%
cust.drop(columns=["count"],inplace=True)
cust
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
data=pd.merge(transc,cust,on="LYLTY_CARD_NBR",how="left")
data
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 246735 2019-03-09        272          272319  270088        89
# 246736 2018-08-13        272          272358  270154        74
# 246737 2018-11-06        272          272379  270187        51
# 246738 2018-12-27        272          272379  270188        42
# 246739 2018-09-22        272          272380  270189        74
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         natural chip        compny seasalt         2        6.0
# 1                       ccs nacho cheese             3        6.3
# 2         smiths crinkle cut  chips chicken          2        2.9
# 3         smiths chip thinly  s/cream&onion          5       15.0
# 4       kettle tortilla chpshny&jlpno chili          3       13.8
# ...                                      ...       ...        ...
# 246735   kettle sweet chilli and sour cream          2       10.8
# 246736             tostitos splash of  lime          1        4.4
# 246737                  doritos mexicana             2        8.8
# 246738   doritos corn chip mexican jalapeno          2        7.8
# 246739             tostitos splash of  lime          2        8.8
#
#         Pkg_size_grm     BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 0                175   natural   YOUNG SINGLES/COUPLES          Premium
# 1                175       ccs  MIDAGE SINGLES/COUPLES           Budget
# 2                170    smiths  MIDAGE SINGLES/COUPLES           Budget
# 3                175    smiths  MIDAGE SINGLES/COUPLES           Budget
# 4                150    kettle  MIDAGE SINGLES/COUPLES           Budget
# ...              ...       ...                     ...              ...
# 246735           175    kettle   YOUNG SINGLES/COUPLES          Premium
# 246736           175  tostitos   YOUNG SINGLES/COUPLES          Premium
# 246737           170   doritos   YOUNG SINGLES/COUPLES          Premium
# 246738           150   doritos   YOUNG SINGLES/COUPLES          Premium
# 246739           175  tostitos   YOUNG SINGLES/COUPLES          Premium
#
# [246740 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246740 entries, 0 to 246739
# Data columns (total 12 columns):
# DATE                246740 non-null datetime64[ns]
# STORE_NBR           246740 non-null int64
# LYLTY_CARD_NBR      246740 non-null int64
# TXN_ID              246740 non-null int64
# PROD_NBR            246740 non-null int64
# PROD_NAME           246740 non-null object
# PROD_QTY            246740 non-null int64
# TOT_SALES           246740 non-null float64
# Pkg_size_grm        246740 non-null int32
# BRAND               246740 non-null object
# LIFESTAGE           246740 non-null object
# PREMIUM_CUSTOMER    246740 non-null object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(5), object(4)
# memory usage: 23.5+ MB

# %%
data.to_csv("Merged_Data.csv")

# %%
data[data["LYLTY_CARD_NBR"]==230078]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 30590 2019-05-17        230          230078  232430        68
# 48810 2018-07-18        230          230078  232416         7
# 48811 2018-07-31        230          230078  232417        85
# 48812 2018-09-26        230          230078  232418        90
# 48813 2018-09-29        230          230078  232419         1
# 48814 2018-10-25        230          230078  232420         2
# 48815 2018-10-29        230          230078  232421        87
# 48816 2018-11-18        230          230078  232422        79
# 48817 2018-12-23        230          230078  232424        17
# 48818 2019-01-09        230          230078  232425        63
# 48819 2019-02-18        230          230078  232426        88
# 48820 2019-03-21        230          230078  232427        82
# 48821 2019-05-09        230          230078  232428        15
# 48822 2019-05-12        230          230078  232429        22
# 48823 2019-05-27        230          230078  232431        42
# 48824 2019-06-01        230          230078  232432        17
# 48825 2019-06-20        230          230078  232433        91
#
#                                  PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm  \
# 30590      pringles chicken    salt crips          4       14.8           134
# 48810        smiths crinkle      original          2       11.4           330
# 48811         rrd honey soy       chicken          2        6.0           165
# 48812        tostitos smoked     chipotle          2        8.8           175
# 48813  smiths crinkle cut  chips barbecue          2        5.8           170
# 48814   cobs popd sour crm  &chives chips          2        7.6           110
# 48815  infuzions bbq rib   prawn crackers          2        7.6           110
# 48816   smiths chip thinly  cutsalt/vinegr         2        6.0           175
# 48817       kettle sensations   bbq&maple          2        9.2           150
# 48818              kettle swt pot sea salt         2        8.4           135
# 48819         kettle honey soy    chicken          2       10.8           175
# 48820    smith crinkle cut   mac n cheese          2        5.2           150
# 48821                 twisties cheese              2        9.2           270
# 48822   thins chips         originl saltd          2        6.6           175
# 48823  doritos corn chip mexican jalapeno          2        7.8           150
# 48824       kettle sensations   bbq&maple          2        9.2           150
# 48825                 ccs tasty cheese             2        4.2           175
#
#            BRAND       LIFESTAGE PREMIUM_CUSTOMER
# 30590   pringles  OLDER FAMILIES           Budget
# 48810     smiths  OLDER FAMILIES           Budget
# 48811        red  OLDER FAMILIES           Budget
# 48812   tostitos  OLDER FAMILIES           Budget
# 48813     smiths  OLDER FAMILIES           Budget
# 48814       cobs  OLDER FAMILIES           Budget
# 48815  infuzions  OLDER FAMILIES           Budget
# 48816     smiths  OLDER FAMILIES           Budget
# 48817     kettle  OLDER FAMILIES           Budget
# 48818     kettle  OLDER FAMILIES           Budget
# 48819     kettle  OLDER FAMILIES           Budget
# 48820     smiths  OLDER FAMILIES           Budget
# 48821   twisties  OLDER FAMILIES           Budget
# 48822      thins  OLDER FAMILIES           Budget
# 48823    doritos  OLDER FAMILIES           Budget
# 48824     kettle  OLDER FAMILIES           Budget
# 48825        ccs  OLDER FAMILIES           Budget

# %% [markdown]
# #### TOT_SALES --> Expenditure

# %% [markdown]
# ## Data Analysis

# %%
data.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm  \
# 0    natural chip        compny seasalt         2        6.0           175
# 1                  ccs nacho cheese             3        6.3           175
# 2    smiths crinkle cut  chips chicken          2        2.9           170
# 3    smiths chip thinly  s/cream&onion          5       15.0           175
# 4  kettle tortilla chpshny&jlpno chili          3       13.8           150
#
#      BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 0  natural   YOUNG SINGLES/COUPLES          Premium
# 1      ccs  MIDAGE SINGLES/COUPLES           Budget
# 2   smiths  MIDAGE SINGLES/COUPLES           Budget
# 3   smiths  MIDAGE SINGLES/COUPLES           Budget
# 4   kettle  MIDAGE SINGLES/COUPLES           Budget

# %%
data['TXN_ID'].nunique()
# Out:
# 245255

# %% [markdown]
# #### Who spends the most on chips (total sales), describing customers by lifestage and how premium their general purchasing behaviour is....

# %%
q1=data[['LIFESTAGE','PREMIUM_CUSTOMER','TOT_SALES']].pivot_table(index=['PREMIUM_CUSTOMER','LIFESTAGE'],aggfunc=sum)
q1.sort_values('TOT_SALES',ascending=False,inplace=True)

# %%
fig,ax=plt.subplots(figsize=(50,20))
sns.barplot(x=q1.index,y=q1["TOT_SALES"])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel("(Life Stage,Segment)",fontsize=40)
ax.set_ylabel("Sum of TOT_SALES",fontsize=40)
# Out:
# Text(0, 0.5, 'Sum of TOT_SALES')

# %% [markdown]
# #### More sales are coming from....
# #### 1. Budget-Older Families
# #### 2. Mainstream-YOUNG SINGLES/COUPLES
# #### 3. Mainstream-RETIREES
# #### 4. Budget-YOUNG FAMILIES
# Lets see if higher sales are due to there being more no.of customers in this segment who buy chips

# %% [markdown]
# #### How many customers are in each segment?

# %%
tempo=data.drop_duplicates(subset='LYLTY_CARD_NBR')
tempo['count']=1
comb2=tempo[["LIFESTAGE","PREMIUM_CUSTOMER","count"]].pivot_table(index=["PREMIUM_CUSTOMER","LIFESTAGE"],aggfunc=sum)
comb2.sort_values('count',ascending=False,inplace=True)

fig,ax=plt.subplots(figsize=(50,20))
sns.barplot(x=comb2.index,y=comb2["count"])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel("(Segment,Life Stage)",fontsize=40)
ax.set_ylabel("Count",fontsize=40)
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Mainstream-YOUNG SINGLES/COUPLES
# #### Mainstream-RETIREES
# #### More of people belonging to these segments contribute to more sales in these customer segments....
# #### But this metric isnt a major driver for the sales in the (BUDGET,OLDER FAMILIES) segment
# Higher sales may also come from more quantity of chips being bought per customer. Lets have a look at it

# %% [markdown]
# #### Average no.of units (PROD_Quantity) per customers...

# %%
data.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  Pkg_size_grm  \
# 0    natural chip        compny seasalt         2        6.0           175
# 1                  ccs nacho cheese             3        6.3           175
# 2    smiths crinkle cut  chips chicken          2        2.9           170
# 3    smiths chip thinly  s/cream&onion          5       15.0           175
# 4  kettle tortilla chpshny&jlpno chili          3       13.8           150
#
#      BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 0  natural   YOUNG SINGLES/COUPLES          Premium
# 1      ccs  MIDAGE SINGLES/COUPLES           Budget
# 2   smiths  MIDAGE SINGLES/COUPLES           Budget
# 3   smiths  MIDAGE SINGLES/COUPLES           Budget
# 4   kettle  MIDAGE SINGLES/COUPLES           Budget

# %%
t1=data[['LIFESTAGE','PREMIUM_CUSTOMER','PROD_QTY']].pivot_table(index=['PREMIUM_CUSTOMER','LIFESTAGE'],aggfunc=sum)
r=data.loc[:,['LIFESTAGE','PREMIUM_CUSTOMER']]

# use "comb2" dataframe that we created earlier
q3=pd.merge(t1,comb2,on=['PREMIUM_CUSTOMER','LIFESTAGE'],how='inner')
q3['Avg']=q3['PROD_QTY']/q3['count']
q3.sort_values('Avg',ascending=False,inplace=True)

# %%
fig,ax=plt.subplots(figsize=(50,20))
sns.barplot(x=q3.index,y=q3["Avg"])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel("(Segment,Life Stage)",fontsize=40)
ax.set_ylabel("Average",fontsize=40)
# Out:
# Text(0, 0.5, 'Average')

# %% [markdown]
# #### Not only the avarage quantity of chips bought but also the average price influences the total sales per customer segments

# %% [markdown]
# #### Average sales (TOT_SALES) per customer....

# %%
q4=pd.merge(q1,q3,on=['PREMIUM_CUSTOMER','LIFESTAGE'],how='inner')
q4.drop(columns=['count','Avg'],inplace=True)
q4['Avg_Price_per_unit']=q4['TOT_SALES']/q4['PROD_QTY']
q4.sort_values('Avg_Price_per_unit',ascending=False,inplace=True)

fig,ax=plt.subplots(figsize=(50,20))
sns.barplot(x=q4.index,y=q4["Avg_Price_per_unit"])
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel("(Segment,Life Stage)",fontsize=40)
ax.set_ylabel("Average Price per Unit",fontsize=40)
# Out:
# Text(0, 0.5, 'Average Price per Unit')

# %% [markdown]
# #### Comparing Avg. spend value of Mainstream VS (Budget,Premium) MIDAGE Singles/Couples
# #### Performing an Independent T-TEST

# %%
from scipy.stats import ttest_ind
Main_Mid_SC=data[(data['PREMIUM_CUSTOMER']=='Mainstream') & ((data['LIFESTAGE']=='MIDAGE SINGLES/COUPLES') | (data['LIFESTAGE']=='YOUNG SINGLES/COUPLES' ))]
Not_Main_Mid_SC=data[(data['PREMIUM_CUSTOMER']!='Mainstream') & ((data['LIFESTAGE']=='MIDAGE SINGLES/COUPLES') | (data['LIFESTAGE']=='YOUNG SINGLES/COUPLES'))]
Main_Mid_SC["Avg_Price"]=Main_Mid_SC['TOT_SALES']/Main_Mid_SC['PROD_QTY']
Not_Main_Mid_SC["Avg_Price"]=Not_Main_Mid_SC['TOT_SALES']/Not_Main_Mid_SC['PROD_QTY']

# Conducting the Independent t-test between the different groups
test=ttest_ind(Main_Mid_SC['Avg_Price'],Not_Main_Mid_SC['Avg_Price'])
print('*************')
print(test)
print('*************')
# Out:
# *************
# Ttest_indResult(statistic=37.83196107667815, pvalue=2.235645611549355e-309)
# *************
# C:\Python\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Python\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# #### The p-value is below the significance level!
# #### So we can reject the Null Hypothesis and say that the Avg. Price per unit of Mainstream Midage and Young singles/couples is significantly higher than their Budget and Premium Counterparts!

# %% [markdown]
# ## Deep dive into Mainstream, Young singles/couples
# ## Performing an Affinity/Apriori Analysis

# %%
data['Segment']=data['PREMIUM_CUSTOMER']+data['LIFESTAGE']

# For Brand of Chips and Size of Chips 
seg_brand=data[['Segment','BRAND']]
seg_brand

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
sb_array=np.array(seg_brand)
te_sb=te.fit(sb_array).transform(sb_array)
te_sb
# Out:
# array([[False, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
sb_df=pd.DataFrame(te_sb,columns=te.columns_)
sb_df
# Out:
#         BudgetMIDAGE SINGLES/COUPLES  BudgetNEW FAMILIES  \
# 0                              False               False
# 1                               True               False
# 2                               True               False
# 3                               True               False
# 4                               True               False
# ...                              ...                 ...
# 246735                         False               False
# 246736                         False               False
# 246737                         False               False
# 246738                         False               False
# 246739                         False               False
#
#         BudgetOLDER FAMILIES  BudgetOLDER SINGLES/COUPLES  BudgetRETIREES  \
# 0                      False                        False           False
# 1                      False                        False           False
# 2                      False                        False           False
# 3                      False                        False           False
# 4                      False                        False           False
# ...                      ...                          ...             ...
# 246735                 False                        False           False
# 246736                 False                        False           False
# 246737                 False                        False           False
# 246738                 False                        False           False
# 246739                 False                        False           False
#
#         BudgetYOUNG FAMILIES  BudgetYOUNG SINGLES/COUPLES  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
# ...                      ...                          ...
# 246735                 False                        False
# 246736                 False                        False
# 246737                 False                        False
# 246738                 False                        False
# 246739                 False                        False
#
#         MainstreamMIDAGE SINGLES/COUPLES  MainstreamNEW FAMILIES  \
# 0                                  False                   False
# 1                                  False                   False
# 2                                  False                   False
# 3                                  False                   False
# 4                                  False                   False
# ...                                  ...                     ...
# 246735                             False                   False
# 246736                             False                   False
# 246737                             False                   False
# 246738                             False                   False
# 246739                             False                   False
#
#         MainstreamOLDER FAMILIES  ...  natural  pringles    red  smiths  \
# 0                          False  ...     True     False  False   False
# 1                          False  ...    False     False  False   False
# 2                          False  ...    False     False  False    True
# 3                          False  ...    False     False  False    True
# 4                          False  ...    False     False  False   False
# ...                          ...  ...      ...       ...    ...     ...
# 246735                     False  ...    False     False  False   False
# 246736                     False  ...    False     False  False   False
# 246737                     False  ...    False     False  False   False
# 246738                     False  ...    False     False  False   False
# 246739                     False  ...    False     False  False   False
#
#         sunbites  thins  tostitos  twisties  tyrrells  woolworths
# 0          False  False     False     False     False       False
# 1          False  False     False     False     False       False
# 2          False  False     False     False     False       False
# 3          False  False     False     False     False       False
# 4          False  False     False     False     False       False
# ...          ...    ...       ...       ...       ...         ...
# 246735     False  False     False     False     False       False
# 246736     False  False      True     False     False       False
# 246737     False  False     False     False     False       False
# 246738     False  False     False     False     False       False
# 246739     False  False      True     False     False       False
#
# [246740 rows x 40 columns]

# %%
frequent_brands=apriori(sb_df,min_support=0.01,use_colnames=True)
frequent_brands
# Out:
#      support                                   itemsets
# 0   0.019012             (BudgetMIDAGE SINGLES/COUPLES)
# 1   0.011445                       (BudgetNEW FAMILIES)
# 2   0.087193                     (BudgetOLDER FAMILIES)
# 3   0.069596              (BudgetOLDER SINGLES/COUPLES)
# 4   0.057652                           (BudgetRETIREES)
# 5   0.071991                     (BudgetYOUNG FAMILIES)
# 6   0.034745              (BudgetYOUNG SINGLES/COUPLES)
# 7   0.044966         (MainstreamMIDAGE SINGLES/COUPLES)
# 8   0.053664                 (MainstreamOLDER FAMILIES)
# 9   0.069146          (MainstreamOLDER SINGLES/COUPLES)
# 10  0.080935                       (MainstreamRETIREES)
# 11  0.048419                 (MainstreamYOUNG FAMILIES)
# 12  0.079209          (MainstreamYOUNG SINGLES/COUPLES)
# 13  0.030850            (PremiumMIDAGE SINGLES/COUPLES)
# 14  0.042162                    (PremiumOLDER FAMILIES)
# 15  0.067115             (PremiumOLDER SINGLES/COUPLES)
# 16  0.049591                          (PremiumRETIREES)
# 17  0.043706                    (PremiumYOUNG FAMILIES)
# 18  0.023717             (PremiumYOUNG SINGLES/COUPLES)
# 19  0.018445                                      (ccs)
# 20  0.011863                                  (cheetos)
# 21  0.018655                                 (cheezels)
# 22  0.039284                                     (cobs)
# 23  0.102229                                  (doritos)
# 24  0.057555                                (infuzions)
# 25  0.167334                                   (kettle)
# 26  0.030271                                  (natural)
# 27  0.101735                                 (pringles)
# 28  0.066147                                      (red)
# 29  0.123016                                   (smiths)
# 30  0.043560                                 (sunbites)
# 31  0.057044                                    (thins)
# 32  0.038385                                 (tostitos)
# 33  0.038316                                 (twisties)
# 34  0.026108                                 (tyrrells)
# 35  0.047970                               (woolworths)
# 36  0.013455             (BudgetOLDER FAMILIES, kettle)
# 37  0.011948             (BudgetOLDER FAMILIES, smiths)
# 38  0.012422      (BudgetOLDER SINGLES/COUPLES, kettle)
# 39  0.010505                   (BudgetRETIREES, kettle)
# 40  0.011117             (BudgetYOUNG FAMILIES, kettle)
# 41  0.011490  (MainstreamOLDER SINGLES/COUPLES, kettle)
# 42  0.013723               (MainstreamRETIREES, kettle)
# 43  0.015579  (MainstreamYOUNG SINGLES/COUPLES, kettle)
# 44  0.011944     (PremiumOLDER SINGLES/COUPLES, kettle)

# %% [markdown]
# So here the "Mainstream" segment customers prefer to buy the Brand "Kettle".
# But the support value is really low but it gives us a freq of almost 15000.....is that a considerable amount to take into consideration?
# So....

# %% [markdown]
# ## Association Rule Mining for (Customer segment,Brand)

# %%
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent_brands,metric='confidence',min_threshold=0.01)
rules
# Out:
#                           antecedents                        consequents  \
# 0              (BudgetOLDER FAMILIES)                           (kettle)
# 1                            (kettle)             (BudgetOLDER FAMILIES)
# 2              (BudgetOLDER FAMILIES)                           (smiths)
# 3                            (smiths)             (BudgetOLDER FAMILIES)
# 4       (BudgetOLDER SINGLES/COUPLES)                           (kettle)
# 5                            (kettle)      (BudgetOLDER SINGLES/COUPLES)
# 6                    (BudgetRETIREES)                           (kettle)
# 7                            (kettle)                   (BudgetRETIREES)
# 8              (BudgetYOUNG FAMILIES)                           (kettle)
# 9                            (kettle)             (BudgetYOUNG FAMILIES)
# 10  (MainstreamOLDER SINGLES/COUPLES)                           (kettle)
# 11                           (kettle)  (MainstreamOLDER SINGLES/COUPLES)
# 12               (MainstreamRETIREES)                           (kettle)
# 13                           (kettle)               (MainstreamRETIREES)
# 14  (MainstreamYOUNG SINGLES/COUPLES)                           (kettle)
# 15                           (kettle)  (MainstreamYOUNG SINGLES/COUPLES)
# 16     (PremiumOLDER SINGLES/COUPLES)                           (kettle)
# 17                           (kettle)     (PremiumOLDER SINGLES/COUPLES)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.087193            0.167334  0.013455    0.154318  0.922216
# 1             0.167334            0.087193  0.013455    0.080411  0.922216
# 2             0.087193            0.123016  0.011948    0.137027  1.113895
# 3             0.123016            0.087193  0.011948    0.097124  1.113895
# 4             0.069596            0.167334  0.012422    0.178488  1.066658
# 5             0.167334            0.069596  0.012422    0.074235  1.066658
# 6             0.057652            0.167334  0.010505    0.182214  1.088926
# 7             0.167334            0.057652  0.010505    0.062779  1.088926
# 8             0.071991            0.167334  0.011117    0.154422  0.922837
# 9             0.167334            0.071991  0.011117    0.066436  0.922837
# 10            0.069146            0.167334  0.011490    0.166168  0.993034
# 11            0.167334            0.069146  0.011490    0.068664  0.993034
# 12            0.080935            0.167334  0.013723    0.169554  1.013269
# 13            0.167334            0.080935  0.013723    0.082009  1.013269
# 14            0.079209            0.167334  0.015579    0.196684  1.175400
# 15            0.167334            0.079209  0.015579    0.093102  1.175400
# 16            0.067115            0.167334  0.011944    0.177959  1.063495
# 17            0.167334            0.067115  0.011944    0.071377  1.063495
#
#     leverage  conviction
# 0  -0.001135    0.984609
# 1  -0.001135    0.992625
# 2   0.001222    1.016236
# 3   0.001222    1.010999
# 4   0.000776    1.013578
# 5   0.000776    1.005011
# 6   0.000858    1.018196
# 7   0.000858    1.005470
# 8  -0.000930    0.984730
# 9  -0.000930    0.994050
# 10 -0.000081    0.998602
# 11 -0.000081    0.999483
# 12  0.000180    1.002674
# 13  0.000180    1.001170
# 14  0.002325    1.036537
# 15  0.002325    1.015320
# 16  0.000713    1.012925
# 17  0.000713    1.004589

# %% [markdown]
# Mainstream-Young Singles/Couples =======> Kettle Gives us a Confidence of 0.19...
# 1. Which means that out of all the transactions which contain "Mainstream-Young Singles/Couples" segment customer....19% of the time a chip belonging to brand "Kettle" is purchased.

# %% [markdown]
# ## Now for Packet size and Customer Segment

# %%
# For Customer Segment and Packet Size 
seg_size=data[['Segment','Pkg_size_grm']]
convert_dict = {'Segment': str,
                'Pkg_size_grm': str
               }
seg_size = seg_size.astype(convert_dict)

ss_array=np.array(seg_size)
te_ss=te.fit(ss_array).transform(ss_array)
te_ss

ss_df=pd.DataFrame(te_ss,columns=te.columns_)
ss_df
# Out:
#           110    125    134    135    150    160    165    170    175    180  \
# 0       False  False  False  False  False  False  False  False   True  False
# 1       False  False  False  False  False  False  False  False   True  False
# 2       False  False  False  False  False  False  False   True  False  False
# 3       False  False  False  False  False  False  False  False   True  False
# 4       False  False  False  False   True  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 246735  False  False  False  False  False  False  False  False   True  False
# 246736  False  False  False  False  False  False  False  False   True  False
# 246737  False  False  False  False  False  False  False   True  False  False
# 246738  False  False  False  False   True  False  False  False  False  False
# 246739  False  False  False  False  False  False  False  False   True  False
#
#         ...  MainstreamRETIREES  MainstreamYOUNG FAMILIES  \
# 0       ...               False                     False
# 1       ...               False                     False
# 2       ...               False                     False
# 3       ...               False                     False
# 4       ...               False                     False
# ...     ...                 ...                       ...
# 246735  ...               False                     False
# 246736  ...               False                     False
# 246737  ...               False                     False
# 246738  ...               False                     False
# 246739  ...               False                     False
#
#         MainstreamYOUNG SINGLES/COUPLES  PremiumMIDAGE SINGLES/COUPLES  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
# ...                                 ...                            ...
# 246735                            False                          False
# 246736                            False                          False
# 246737                            False                          False
# 246738                            False                          False
# 246739                            False                          False
#
#         PremiumNEW FAMILIES  PremiumOLDER FAMILIES  \
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 246735                False                  False
# 246736                False                  False
# 246737                False                  False
# 246738                False                  False
# 246739                False                  False
#
#         PremiumOLDER SINGLES/COUPLES  PremiumRETIREES  PremiumYOUNG FAMILIES  \
# 0                              False            False                  False
# 1                              False            False                  False
# 2                              False            False                  False
# 3                              False            False                  False
# 4                              False            False                  False
# ...                              ...              ...                    ...
# 246735                         False            False                  False
# 246736                         False            False                  False
# 246737                         False            False                  False
# 246738                         False            False                  False
# 246739                         False            False                  False
#
#         PremiumYOUNG SINGLES/COUPLES
# 0                               True
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 246735                          True
# 246736                          True
# 246737                          True
# 246738                          True
# 246739                          True
#
# [246740 rows x 41 columns]

# %%
frequent_size=apriori(ss_df,min_support=0.01,use_colnames=True)
frequent_size
# Out:
#      support                                 itemsets
# 0   0.090731                                    (110)
# 1   0.101735                                    (134)
# 2   0.013200                                    (135)
# 3   0.162937                                    (150)
# 4   0.012037                                    (160)
# 5   0.061996                                    (165)
# 6   0.080988                                    (170)
# 7   0.269069                                    (175)
# 8   0.012138                                    (190)
# 9   0.018128                                    (200)
# 10  0.025419                                    (210)
# 11  0.012843                                    (250)
# 12  0.025472                                    (270)
# 13  0.050823                                    (330)
# 14  0.026003                                    (380)
# 15  0.012191                                     (90)
# 16  0.019012           (BudgetMIDAGE SINGLES/COUPLES)
# 17  0.011445                     (BudgetNEW FAMILIES)
# 18  0.087193                   (BudgetOLDER FAMILIES)
# 19  0.069596            (BudgetOLDER SINGLES/COUPLES)
# 20  0.057652                         (BudgetRETIREES)
# 21  0.071991                   (BudgetYOUNG FAMILIES)
# 22  0.034745            (BudgetYOUNG SINGLES/COUPLES)
# 23  0.044966       (MainstreamMIDAGE SINGLES/COUPLES)
# 24  0.053664               (MainstreamOLDER FAMILIES)
# 25  0.069146        (MainstreamOLDER SINGLES/COUPLES)
# 26  0.080935                     (MainstreamRETIREES)
# 27  0.048419               (MainstreamYOUNG FAMILIES)
# 28  0.079209        (MainstreamYOUNG SINGLES/COUPLES)
# 29  0.030850          (PremiumMIDAGE SINGLES/COUPLES)
# 30  0.042162                  (PremiumOLDER FAMILIES)
# 31  0.067115           (PremiumOLDER SINGLES/COUPLES)
# 32  0.049591                        (PremiumRETIREES)
# 33  0.043706                  (PremiumYOUNG FAMILIES)
# 34  0.023717           (PremiumYOUNG SINGLES/COUPLES)
# 35  0.014542              (BudgetOLDER FAMILIES, 150)
# 36  0.011393       (BudgetOLDER SINGLES/COUPLES, 150)
# 37  0.011599              (BudgetYOUNG FAMILIES, 150)
# 38  0.011239   (MainstreamOLDER SINGLES/COUPLES, 150)
# 39  0.013334                (MainstreamRETIREES, 150)
# 40  0.012483   (MainstreamYOUNG SINGLES/COUPLES, 150)
# 41  0.011218      (PremiumOLDER SINGLES/COUPLES, 150)
# 42  0.023539              (BudgetOLDER FAMILIES, 175)
# 43  0.018744       (175, BudgetOLDER SINGLES/COUPLES)
# 44  0.015591                    (BudgetRETIREES, 175)
# 45  0.019944              (175, BudgetYOUNG FAMILIES)
# 46  0.012057  (MainstreamMIDAGE SINGLES/COUPLES, 175)
# 47  0.014542          (175, MainstreamOLDER FAMILIES)
# 48  0.018339   (175, MainstreamOLDER SINGLES/COUPLES)
# 49  0.021460                (175, MainstreamRETIREES)
# 50  0.012864          (175, MainstreamYOUNG FAMILIES)
# 51  0.020252   (MainstreamYOUNG SINGLES/COUPLES, 175)
# 52  0.011413             (175, PremiumOLDER FAMILIES)
# 53  0.018068      (PremiumOLDER SINGLES/COUPLES, 175)
# 54  0.013399                   (PremiumRETIREES, 175)
# 55  0.012150             (PremiumYOUNG FAMILIES, 175)

# %% [markdown]
# ## Association Rule Mining for (Customer Segment,Packet Size)

# %%
rules_ss=association_rules(frequent_size,metric='confidence',min_threshold=0.01)
rules_ss
# Out:
#                            antecedents                         consequents  \
# 0               (BudgetOLDER FAMILIES)                               (150)
# 1                                (150)              (BudgetOLDER FAMILIES)
# 2        (BudgetOLDER SINGLES/COUPLES)                               (150)
# 3                                (150)       (BudgetOLDER SINGLES/COUPLES)
# 4               (BudgetYOUNG FAMILIES)                               (150)
# 5                                (150)              (BudgetYOUNG FAMILIES)
# 6    (MainstreamOLDER SINGLES/COUPLES)                               (150)
# 7                                (150)   (MainstreamOLDER SINGLES/COUPLES)
# 8                 (MainstreamRETIREES)                               (150)
# 9                                (150)                (MainstreamRETIREES)
# 10   (MainstreamYOUNG SINGLES/COUPLES)                               (150)
# 11                               (150)   (MainstreamYOUNG SINGLES/COUPLES)
# 12      (PremiumOLDER SINGLES/COUPLES)                               (150)
# 13                               (150)      (PremiumOLDER SINGLES/COUPLES)
# 14              (BudgetOLDER FAMILIES)                               (175)
# 15                               (175)              (BudgetOLDER FAMILIES)
# 16                               (175)       (BudgetOLDER SINGLES/COUPLES)
# 17       (BudgetOLDER SINGLES/COUPLES)                               (175)
# 18                    (BudgetRETIREES)                               (175)
# 19                               (175)                    (BudgetRETIREES)
# 20                               (175)              (BudgetYOUNG FAMILIES)
# 21              (BudgetYOUNG FAMILIES)                               (175)
# 22  (MainstreamMIDAGE SINGLES/COUPLES)                               (175)
# 23                               (175)  (MainstreamMIDAGE SINGLES/COUPLES)
# 24                               (175)          (MainstreamOLDER FAMILIES)
# 25          (MainstreamOLDER FAMILIES)                               (175)
# 26                               (175)   (MainstreamOLDER SINGLES/COUPLES)
# 27   (MainstreamOLDER SINGLES/COUPLES)                               (175)
# 28                               (175)                (MainstreamRETIREES)
# 29                (MainstreamRETIREES)                               (175)
# 30                               (175)          (MainstreamYOUNG FAMILIES)
# 31          (MainstreamYOUNG FAMILIES)                               (175)
# 32   (MainstreamYOUNG SINGLES/COUPLES)                               (175)
# 33                               (175)   (MainstreamYOUNG SINGLES/COUPLES)
# 34                               (175)             (PremiumOLDER FAMILIES)
# 35             (PremiumOLDER FAMILIES)                               (175)
# 36      (PremiumOLDER SINGLES/COUPLES)                               (175)
# 37                               (175)      (PremiumOLDER SINGLES/COUPLES)
# 38                   (PremiumRETIREES)                               (175)
# 39                               (175)                   (PremiumRETIREES)
# 40             (PremiumYOUNG FAMILIES)                               (175)
# 41                               (175)             (PremiumYOUNG FAMILIES)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.087193            0.162937  0.014542    0.166775  1.023558
# 1             0.162937            0.087193  0.014542    0.089247  1.023558
# 2             0.069596            0.162937  0.011393    0.163697  1.004665
# 3             0.162937            0.069596  0.011393    0.069920  1.004665
# 4             0.071991            0.162937  0.011599    0.161121  0.988859
# 5             0.162937            0.071991  0.011599    0.071189  0.988859
# 6             0.069146            0.162937  0.011239    0.162534  0.997531
# 7             0.162937            0.069146  0.011239    0.068975  0.997531
# 8             0.080935            0.162937  0.013334    0.164747  1.011111
# 9             0.162937            0.080935  0.013334    0.081835  1.011111
# 10            0.079209            0.162937  0.012483    0.157593  0.967205
# 11            0.162937            0.079209  0.012483    0.076611  0.967205
# 12            0.067115            0.162937  0.011218    0.167150  1.025857
# 13            0.162937            0.067115  0.011218    0.068851  1.025857
# 14            0.087193            0.269069  0.023539    0.269964  1.003327
# 15            0.269069            0.087193  0.023539    0.087483  1.003327
# 16            0.269069            0.069596  0.018744    0.069664  1.000985
# 17            0.069596            0.269069  0.018744    0.269334  1.000985
# 18            0.057652            0.269069  0.015591    0.270439  1.005094
# 19            0.269069            0.057652  0.015591    0.057945  1.005094
# 20            0.269069            0.071991  0.019944    0.074123  1.029613
# 21            0.071991            0.269069  0.019944    0.277037  1.029613
# 22            0.044966            0.269069  0.012057    0.268139  0.996544
# 23            0.269069            0.044966  0.012057    0.044811  0.996544
# 24            0.269069            0.053664  0.014542    0.054044  1.007091
# 25            0.053664            0.269069  0.014542    0.270977  1.007091
# 26            0.269069            0.069146  0.018339    0.068158  0.985714
# 27            0.069146            0.269069  0.018339    0.265225  0.985714
# 28            0.269069            0.080935  0.021460    0.079756  0.985428
# 29            0.080935            0.269069  0.021460    0.265148  0.985428
# 30            0.269069            0.048419  0.012864    0.047808  0.987381
# 31            0.048419            0.269069  0.012864    0.265673  0.987381
# 32            0.079209            0.269069  0.020252    0.255679  0.950239
# 33            0.269069            0.079209  0.020252    0.075267  0.950239
# 34            0.269069            0.042162  0.011413    0.042416  1.006030
# 35            0.042162            0.269069  0.011413    0.270691  1.006030
# 36            0.067115            0.269069  0.018068    0.269203  1.000499
# 37            0.269069            0.067115  0.018068    0.067149  1.000499
# 38            0.049591            0.269069  0.013399    0.270186  1.004154
# 39            0.269069            0.049591  0.013399    0.049797  1.004154
# 40            0.043706            0.269069  0.012150    0.278004  1.033210
# 41            0.269069            0.043706  0.012150    0.045157  1.033210
#
#     leverage  conviction
# 0   0.000335    1.004607
# 1   0.000335    1.002255
# 2   0.000053    1.000909
# 3   0.000053    1.000349
# 4  -0.000131    0.997836
# 5  -0.000131    0.999136
# 6  -0.000028    0.999520
# 7  -0.000028    0.999817
# 8   0.000147    1.002168
# 9   0.000147    1.000979
# 10 -0.000423    0.993657
# 11 -0.000423    0.997187
# 12  0.000283    1.005059
# 13  0.000283    1.001864
# 14  0.000078    1.001226
# 15  0.000078    1.000318
# 16  0.000018    1.000074
# 17  0.000018    1.000363
# 18  0.000079    1.001879
# 19  0.000079    1.000312
# 20  0.000574    1.002303
# 21  0.000574    1.011021
# 22 -0.000042    0.998729
# 23 -0.000042    0.999837
# 24  0.000102    1.000402
# 25  0.000102    1.002617
# 26 -0.000266    0.998940
# 27 -0.000266    0.994769
# 28 -0.000317    0.998718
# 29 -0.000317    0.994664
# 30 -0.000164    0.999358
# 31 -0.000164    0.995376
# 32 -0.001061    0.982012
# 33 -0.001061    0.995738
# 34  0.000068    1.000265
# 35  0.000068    1.002225
# 36  0.000009    1.000184
# 37  0.000009    1.000036
# 38  0.000055    1.001531
# 39  0.000055    1.000217
# 40  0.000391    1.012377
# 41  0.000391    1.001520

# %% [markdown]
# We have 2 rules here.....
# 1. Mainstream-Young Singles/Couples========>150 with Support = 0.012483,Confidence=0.157593,Lift=0.967205. Which means that out of all the Transactions involving Mainstream-Young Singles/Couples...15% of the time they choose a chips packet of size 150g
# 2. Mainstream-Young Singles/Couples ========> 175 with Support=0.020252,Confidence=0.255679,Lift=0.950239. Which means that oout of all the Transactions involving Mainstream-Young Singles/Couples...25% of the time they choose a chips packet of size 175g.
# the 175 has greater overall support and confidence but....150 has slightly Lift.
